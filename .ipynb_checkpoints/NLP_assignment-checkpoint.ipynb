# %%
french_stopwords = ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle', 'en', 'et', 'eux', 'il', 'ils', 'ha', 'je', 'la', 'le', 'les', 'leur', 'lui', 'ma', 'mais', 'me', 'même', 'mes', 'moi', 'mon', 'ne', 'nos', 'notre', 'nous', 'on', 'ou', 'par', 'pas', 'pour', 'qu', 'que', 'qui', 'sa', 'se', 'ses', 'son', 'sur', 'ta', 'te', 'tes', 'toi', 'ton', 'tu', 'un', 'une', 'vos', 'votre', 'vous', 'c', 'd', 'j', 'l', 'à', 'm', 'n', 's', 't', 'y', 'été', 'étée', 'étées', 'étés', 'étant', 'étante', 'étants', 'étantes', 'suis', 'es', 'est', 'sommes', 'êtes', 'sont', 'serai', 'seras', 'sera', 'serons', 'serez', 'seront', 'serais', 'serait', 'serions', 'seriez', 'seraient', 'étais', 'était', 'étions', 'étiez', 'étaient', 'fus', 'fut', 'fûmes', 'fûtes', 'furent', 'sois', 'soit', 'soyons', 'soyez', 'soient', 'fusse', 'fusses', 'fût', 'fussions', 'fussiez', 'fussent', 'ayant', 'ayante', 'ayantes', 'ayants', 'eu', 'eue', 'eues', 'eus', 'ai', 'as', 'avons', 'avez', 'ont', 'aurai', 'auras', 'aura', 'aurons', 'aurez', 'auront', 'aurais', 'aurait', 'aurions', 'auriez', 'auraient', 'avais', 'avait', 'avions', 'aviez', 'avaient', 'eut', 'eûmes', 'eûtes', 'eurent', 'aie', 'aies', 'ait', 'ayons', 'ayez', 'aient', 'eusse', 'eusses', 'eût', 'eussions', 'eussiez', 'eussent']

# %%
import pandas as pd
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
labels = []

for sentence in train_data['text']:
    text_tokens = sentence.split()
    for i in range(0, len(text_tokens)): 
         isFrench = False 
         
         for j in range(0, len(french_stopwords)):    
                if(text_tokens[i] == french_stopwords[j]):  
                      labels.append("French")
                      isFrench = True
                      break
         
         if isFrench == True:
            break
          
    if isFrench == False:
            labels.append("English")

# %%
train_data['target'] = labels

# %%
train_data.head(40)
# Out:
#     Unnamed: 0                                               text   target
# 0        13099    Oland â 96 ha, 1 Warft, environ 30 habitants.  English
# 1        14620  Les dÃ©pÃ´ts judiciaires montrent que FPI US L...   French
# 2         7651       Costumes: Beatrice Dawson et Christian Dior.   French
# 3        19227  Le No-Go decay (NGD) est le mÃ©canisme de surv...   French
# 4         1427  This was followed in 1992 by Evolution II, whe...  English
# 5        11279  Ã la fin fÃ©vrier 2003 est tombÃ© un autre ju...   French
# 6        18932  Un seul festival Sekar est attestÃ© par des Ã©...   French
# 7        11692  La Constitution de 1972 du Bangladesh compris ...   French
# 8         4349                          Henri Salvador took four.  English
# 9        13141  Un nombre relativement faible de femmes travai...   French
# 10       10726  LâÃ©difice subit une importante rÃ©novation ...   French
# 11         283  Fincher liked the concept and it became the ma...  English
# 12       11000  Les premiers membres de la mission Dixie arriv...   French
# 13       15329  La chanson devient trÃ¨s populaire en Iran et ...   French
# 14        5132  Several methods of processing are then used (i...  English
# 15         810  Gladiators were used also by 263 Squadron duri...  English
# 16        6237  After his mother's death in 1915 he lived in a...  English
# 17        5351  Azulai often records where he has seen in pers...  English
# 18        5151  The hospital attracted over 2,000 female patie...  English
# 19        8353  After considerable public pressure, the Coast ...  English
# 20       10924  L'utilisation du mot par une femme dans d'autr...   French
# 21       19269  Le dÃ©partement de police de Summerside a Ã  p...   French
# 22       15461  Ce terrain servit aussi beaucoup plus tard, pe...   French
# 23       18630  Ã la fin du XIXeÂ siÃ¨cle, le Dr Shunichi Shi...   French
# 24        1339  Well what kind of law are you following, that ...  English
# 25       10209  Il Ã©tait considÃ©rÃ© un thÃ©ologien cÃ©lÃ¨bre...   French
# 26        9635  The Tragedy of Jane Shore is a 1714 play by Ni...  English
# 27       12358  Jean de Hainault avait Ã©galement participÃ© Ã...   French
# 28       10102  Comme les interrelations spatiales sont la clÃ...   French
# 29       12050       Ceci prit le nom de compromis de Luxembourg.   French
# 30       10542  Il a Ã©galement participÃ© activement Ã  la cr...   French
# 31        6466  It was only after 1946 that the after section ...  English
# 32        9949  When entering the Edo period, the ashigaru's p...  English
# 33        2033  When people think of a dinosaur, they think of...  English
# 34       14919  Ils ont Ã©galement crÃ©Ã© le studio d'enregist...   French
# 35        7737  Bourdelle did several studies to produce a sma...   French
# 36       15624         Elle est tuÃ©e par Kaede dans le volume 3.   French
# 37       11760  En 2007, il avait pris sa retraite des mission...   French
# 38        9690  Both women were from Athens but the nature of ...  English
# 39       14475  Les historiens modernes suggÃ¨rent que Ibn Kha...   French
